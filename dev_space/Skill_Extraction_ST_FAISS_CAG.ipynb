# %% [markdown]
# # Skill Extraction with CAG
# **Objective:** Extract relevant skills from text by first retrieving a candidate set using semantic search (MPNet embeddings + FAISS) and then using an LLM (Gemma via VLLM) to refine selections from these candidates.
# - **Date:** 9-June-25
# - **Author:** Anket Patil

# %% [markdown]
# ## 1. Install Dependencies
# Installs required libraries:
#
# * `faiss-cpu`: For similarity search.
# * `sentence-transformers`: Create embeddings

# %%
# !pip install -q sentence-transformers faiss-cpu
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 31.3/31.3 MB 22.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 82.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 76.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 44.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 14.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 108.8 MB/s eta 0:00:00

# %% [markdown]
# ## 2. Import Libraries
# Imports essential Python libraries for data handling, numerical operations, model interaction, and FAISS.

# %%
import os
import numpy as np
import pandas as pd
from sentence_transformers import SentenceTransformer, util
import faiss
import time
import random

# %% [markdown]
# ## 3. Create FAISS Index for Semantic Search
# Loads ESCO skills, turns them into vectors using a all-mpnet-base-v2, and builds a FAISS index so we can quickly find the most relevant skills for any course or job description.

# %%
# Load ESCO skill data
esco_df = pd.read_csv("https://raw.githubusercontent.com/LAiSER-Software/datasets/refs/heads/master/taxonomies/ESCO_skills_Taxonomy.csv")  # replace with your file if needed
skill_names = esco_df["preferredLabel"].tolist()

# Embed ESCO skills using SentenceTransformer
model = SentenceTransformer('sentence-transformers/all-mpnet-base-v2')
print("Embedding ESCO skills...")
esco_embeddings = model.encode(skill_names, convert_to_numpy=True, show_progress_bar=True)

# ⚡ Normalize & Index using FAISS (cosine sim = L2 norm + dot product)
dimension = esco_embeddings.shape[1]
index = faiss.IndexFlatIP(dimension)
faiss.normalize_L2(esco_embeddings)
index.add(esco_embeddings)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.4k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Embedding ESCO skills...
# Batches:   0%|          | 0/436 [00:00<?, ?it/s]

# %% [markdown]
# ## 4. Find Most Relevant ESCO Skills
# Takes a course description, turns it into a vector using the embedding model, and searches the FAISS index to return the top 50 most relevant ESCO skills based on similarity.

# %%
def get_top_esco_skills(course_desc, top_k=50):
    emb = model.encode(course_desc, convert_to_numpy=True)
    faiss.normalize_L2(emb.reshape(1, -1))
    scores, indices = index.search(emb.reshape(1, -1), top_k)
    return [skill_names[i] for i in indices[0]]

# %% [markdown]
# ## 5.  Load Syllabi Dataset
# Loads a preprocessed dataset of 50 course syllabi from OpenSyllabus

# %%
syllabi_data = pd.read_csv("https://raw.githubusercontent.com/LAiSER-Software/datasets/refs/heads/master/syllabi-data/preprocessed_50_opensyllabus_syllabi_data.csv")
syllabi_data
# Out:
#                 id                                              title  \
# 0    4904852663176                                  Film Appreciation
# 1     661424964946                          Quality Improvement Tools
# 2    6004364299427                 Data Privacy, Security, and Ethics
# 3    8014409002470                                  Consumer Behavior
# 4   15728170259237                        General Organic Chemistry I
# 5   16097537445411                                   Physical Geology
# 6   15350213134595                  Writing Competency through Genres
# 7     274877917243                                 ADMINISTRATIVE LAW
# 8   14001593392419              Criminal Justice Research and Writing
# 9    7181185329132                                  Computer literacy
# 10   9577777075581                                   Forensic Biology
# 11  17128329598777                   Topics for Mathematical Literacy
# 12   9577777078616             Financial Decision Making for Managers
# 13   8031588852698                      Digital Graphics for Gaming l
# 14   4389456602774                          Intro to Criminal Justice
# 15  10892037082042                        Criminal Evidence And Proof
# 16  10557029632797                         Basic Finance for Managers
# 17   2413771625545                     Lab: Anatomy and Physiology II
# 18   3367254374102                     Generalist Practice in Context
# 19   8976481665318                       Cross Cultural Communication
# 44              NaN     Southampton    50.934631     -1.395950
# 45            Texas     San Antonio    29.424120    -98.493629
# 46            Texas       Galveston    29.284212    -94.808540
# 47            Texas          Odessa    31.867176   -102.383461
# 48    New Hampshire          Durham    43.133968    -70.926453
# 49            Texas         Houston    29.781649    -95.256691
#
#                                        in_description  \
# 0   South Plains College (SPC) is a public communi...
# 1   The Niagara College of Applied Arts and Techno...
# 2   Webster University is a private university wit...
# 3   Upper Iowa University (UIU) is a private unive...
# 4   public community college in Chandler, Arizona,...
# 5   Tyler Junior College (TJC) is a public communi...
# 6   San José State University (San Jose State or S...
# 7   Florida Gulf Coast University (FGCU) is a publ...
# 8   Liberty University (LU) is a private Baptist u...
# 9   Vytautas Magnus University (VMU) (Lithuanian: ...
# 10  Deakin University is a public university in Vi...
# 11  The University of Maryland Global Campus (UMGC...
# 12  The University of Maryland Global Campus (UMGC...
# 13  The Niagara College of Applied Arts and Techno...
# 14  The Alamo Colleges District (previously the Al...
# 15  The University of Aberdeen (Scots: University ...
# 16  Webster University is a private university wit...
# 17  Collin College is a public community college d...
# 18  The University of Calgary (U of C or UCalgary)...
# 19  The University of Adelaide (informally Adelaid...
# 20  Houston Community College (HCC), also known as...
# 21                                                NaN
# 22  Tulsa Community College is a public community ...
# 23  The University of Calgary (U of C or UCalgary)...
# 24  The Austin Community College District (ACC) is...
# 25  Portland Community College (PCC) is a public c...
# 26  The American University of Paris (AUP) is a pr...
# 27  Wesleyan University ( (listen) WESS-lee-ən) is...
# 28  Tyler Junior College (TJC) is a public communi...
# 29  Cambridge College is a private college based i...
# 30  Copiah–Lincoln Community College (Co–Lin) is a...
# 31  The University of Texas at El Paso (UTEP) is a...
# 32  Mendel University in Brno is located in Brno, ...
# 33  ETH Zurich (English: ETH; Swiss Federal Instit...
# 34  The University of Texas at Tyler (UT Tyler) is...
# 35  The University of Maryland Global Campus (UMGC...
# 36  Masaryk University (MU) (Czech: Masarykova uni...
# 37  San Diego State University (SDSU) is a public ...
# 38  Portland Community College (PCC) is a public c...
# 39  Liberty University (LU) is a private Baptist u...
# 40  San Jacinto College (Spanish: Colegio San Jaci...
# 41  Collin College is a public community college d...
# 42  Charles University (Czech: Univerzita Karlova,...
# 43  The University of Maryland Global Campus (UMGC...
# 44  The University of Southampton (abbreviated as ...
# 45  The University of Texas at San Antonio (UTSA) ...
# 46  Galveston College (GC) is a public community c...
# 47  Odessa College is a public junior college in O...
# 48  The University of New Hampshire (UNH) is a pub...
# 49  Houston Community College (HCC), also known as...
#
#                                           description  \
# 0   survey and analysis of cinema , including hist...
# 1   you will be provided with a practical understa...
# 2   there is a subtle balance between improvements...
# 3   this course provides a survey of research find...
# 4   rigorous introduction to chemistry of carbon -...
# 5   introduction to the study of the materials and...
# 6   prepares students for 100w through drafting , ...
# 7   administrative law affects every aspect of ame...
# 8   this course is an introductory course to resea...
# 9   course introduces main concepts of computer sc...
# 10  this unit will focus on a range of biological ...
# 11  an investigation of contemporary topics in mat...
# 12  mgmt 640 combines the study of financial accou...
# 13  this is an introductory course in computer gra...
# 14  this course provides a historical and philosop...
# 15  this course is comparative in nature and exami...
# 16  managers and human resources management profes...
# 17  anatomy and physiology ii is the second part o...
# 18  generalist practice “ in context ” is the core...
# 19  misunderstandings often arise when speakers of...
# 20  anatomy and physiology i is the first part of ...
# 21  in this course , the principle of the operatio...
# 22  a study of the fundamental operations of whole...
# 23  an introduction to fine art printmaking . tech...
# 24  english 1301    is    a study of the principle...
# 25  focuses on demonstrating knowledge of auto bod...
# 26  after studying the principles of morphological...
# 27  this is a seminar exploring the role of geneti...
# 28  fundamentals of engine operation , diagnosis a...
# 29  this course offers students engagement and int...
# 30  this course is designed to give students a cur...
# 31  [ NAME ] [ NAME ] is a required course in the ...
# 32  to familiarize students with the development o...
# 33  the course provides advanced tools for the ris...
# 34  a field - based course to provide superintende...
# 35  a hands - on study of human nutrition . the go...
# 36  the course deals with the basics of human - co...
# 37  the purpose of this class is to give the stude...
# 38  discusses personal and professional ethics wit...
# 39  a group course for students having limited but...
# 40  this course comprises the integration of criti...
# 41  introduces basic human communication principle...
# 42  an introductory course covering basic concepts...
# 43  a survey of the basic principles , research co...
# 44  this module is designed to provide an introduc...
# 45  public relations planning and campaigns is an ...
# 46  development of skills and techniques required ...
# 47  this best - selling guide provides a complete ...
# 48  field - based learning opportunities in the bi...
# 49  this course is exciting because you will learn...
#
#                                     learning_outcomes  year
# 0   communications skills — to include effective w...  2022
# 1   employ statistics to solve problems . use stat...  2022
# 2                                                 NaN  2022
# 3   an overview of consumer behavior and terminolo...  2022
# 4   describe the bonding properties of the element...  2022
# 5   describe how the scientific method has led to ...  2022
# 6   use correct and situationally appropriate sent...  2022
# 7   examine how law affects agencies ’ policymakin...  2022
# 8   research a topic in criminal justice thoroughl...  2022
# 9   to formalize and specify real - world problems...  2022
# 10  discuss and justify the application of biologi...  2022
# 11  use appropriate formulas , algorithms , and te...  2022
# 12  evaluate the relationship between an organizat...  2022
# 13  apply rudiments of visual design and colour th...  2022
# 14  describe the history and philosophy of the ame...  2022
# 15                                                NaN  2022
# 16  students have a basic familiarity with the fie...  2022
# 17  use anatomical terminology to identify and des...  2022
# 18  demonstrate self - reflection as it relates to...  2022
# 19  understand the importance of cross - cultural ...  2022
# 20  critical thinking skills : to include creative...  2022
# 21  to describe the physical operation of the main...  2022
# 22  communication skills . critical thinking . soc...  2022
# 23  demonstrate an understanding of fundamental pr...  2022
# 24  identify rhetorical purposes and methods of or...  2022
# 25  communicate effectively with employers , cowor...  2022
# 26  deal with details of arabic grammar ( both syn...  2022
# 27                                                NaN  2022
# 28  utilize safety procedures . explain engine ope...  2022
# 29  describe the importance of medical terminology...  2022
# 30  demonstrate and engage appropriate body mechan...  2022
# 31  students will be able to apply the principles ...  2022
# 32  to familiarize students with the development o...  2022
# 33  students will be able to model complex technic...  2022
# 34  the student will be able to understand the res...  2022
# 35  formulate questions and predictions about caus...  2022
# 36  understand the principles of good design and w...  2022
# 37  demonstrate the acquisi on and applica on of m...  2022
# 38  apply self - assessment strategies to identify...  2022
# 39  to further develop understanding of the elemen...  2022
# 40  locate explicit textual information , draw com...  2022
# 41  apply the principles of human communication in...  2022
# 42                                                NaN  2022
# 43  apply major concepts , theoretical perspective...  2022
# 44  the importance of capital structure and divide...  2022
# 45  acquire skills in working with others as a mem...  2022
# 46                                                NaN  2022
# 47  identify major information security threats an...  2022
# 48                                                NaN  2022
# 49  students will learn to interpret the language ...  2022

# %% [markdown]
# ## Test Skill Extraction on a Single Course Description
# This cell randomly selects one course from the dataset, extracts its top 50 relevant ESCO skills using the semantic search pipeline, and displays the time taken for the operation in milliseconds.

# %%
# Randomly pick an index between 0 and 45
rand_idx = random.randint(0, 49)
row = syllabi_data.loc[rand_idx]

course_title = row['title']
course_desc = row['description']

print(f"Course Title: {course_title}")
print(f"Course Description:\n{course_desc}\n")

start_time = time.time()
single_skills = get_top_esco_skills(course_desc)
end_time = time.time()

time_ms = (end_time - start_time) * 1000
print(f"Time taken: {round(time_ms, 2)} ms")
print(f"\nTop 50 ESCO Skills:\n{single_skills}")
# Out:
# Course Title: Financial Decision Making for Managers
# Course Description:
# mgmt 640 combines the study of financial accounting , finance , and managerial accounting into a concentrated one - semester course . business organizations , both for - profit and non - profit , employ financial managers in a wide variety of roles to gather and report on company financial performance ; direct investment decisions ; implement cash management strategies ; prepare budgets and establish operating performance measures ; and participate in the development and implementation of long - term business strategies . this course is an introduction to the management of a firm 's financial and operational resources . it is intended as a foundation - level course in corporate financial management for students pursuing the master of science in management with specialization , or as a perquisite for students enrolled in the financial management and accounting or healthcare degree programs . emphasis is placed on helping students gain an understanding of financial management principles within an overarching conceptual framework , before studying specific concepts in depth . in addition to studying financial management concepts , students are required to learn and demonstrate basic competency in excel as preparation for using this financial management tool in the work place and in future course work .
#
# Time taken: 37.12 ms
#
# Top 50 ESCO Skills:
# ['financial management', 'manage financial aspects of a company', 'accounting techniques', 'use accounting systems', 'accounting', 'develop financial statistics reports', 'supervise accounting operations', 'prepare financial statements', 'optimise financial performance', 'perform cost accounting activities', 'accounting entries', 'financial analysis', 'business analysis', 'perform balance sheet operations', 'cost management', 'prepare financial auditing reports', 'perform business analysis', 'create a financial report', 'manage profitability', 'financial statements', 'financial department processes', 'prepare financial projections', 'analyse financial performance of a company', 'handle cash flow', 'conduct financial audits', 'produce statistical financial records', 'handle financial overviews of the store', 'business management principles', 'interpret financial statements', 'report on overall management of a business', 'accounting department processes', 'draft accounting procedures', 'perform financial market business', 'explain accounting records', 'maintain financial records', 'comprehend financial business terminology', 'manage financial and material resources', 'financial engineering', 'operations management', 'provide support in financial calculation', 'manage budgets', 'control financial resources', 'national generally accepted accounting principles', 'management consulting', 'handle financial transactions', 'collect financial data', 'teach business principles', 'ensure compliance with accounting conventions', 'provide financial product information', 'international financial reporting standards']

# %% [markdown]
# ## Extract Top 50 ESCO Skills for Each Course
# Loops through each course description in the syllabi dataset, uses the get_top_esco_skills function to find the top 50 relevant ESCO skills

# %%
def get_top_k_skills_bulk(df, text_col='description', top_k=50):
    top_skills_list = []
    for i, row in df.iterrows():
        course_desc = row[text_col]
        if not isinstance(course_desc, str) or not course_desc.strip():
            top_skills_list.append([])
            continue

        skills = get_top_esco_skills(course_desc, top_k=top_k)
        top_skills_list.append(skills)

    return top_skills_list

# %%
# ⏱️ Measure total time in milliseconds
start_time = time.time()

# Bulk processing
syllabi_data['top_50_esco_skills'] = get_top_k_skills_bulk(syllabi_data)

end_time = time.time()
total_time_ms = (end_time - start_time) * 1000
print(f"Total time taken for all rows: {round(total_time_ms, 2)} ms")
syllabi_data[['title','description','top_50_esco_skills']]
# Out:
# Total time taken for all rows: 850.72 ms
#                                                 title  \
# 0                                   Film Appreciation
# 1                           Quality Improvement Tools
# 2                  Data Privacy, Security, and Ethics
# 3                                   Consumer Behavior
# 4                         General Organic Chemistry I
# 5                                    Physical Geology
# 6                   Writing Competency through Genres
# 7                                  ADMINISTRATIVE LAW
# 8               Criminal Justice Research and Writing
# 9                                   Computer literacy
# 10                                   Forensic Biology
# 11                   Topics for Mathematical Literacy
# 12             Financial Decision Making for Managers
# 13                      Digital Graphics for Gaming l
# 14                          Intro to Criminal Justice
# 15                        Criminal Evidence And Proof
# 16                         Basic Finance for Managers
# 17                     Lab: Anatomy and Physiology II
# 18                     Generalist Practice in Context
# 19                       Cross Cultural Communication
# 20                       Human Anatomy & Physiology I
# 21  Design and Diagnostics by Image Design and Dia...
# 22                                 MATH FOUNDATIONS I
# 23                        Introduction to Printmaking
# 24                              English Composition I
# 25            Cooperative Education: Auto Body Repair
# 26                              INTERMEDIATE ARABIC I
# 27                                  Behavior Genetics
# 28                           Automotive Engine Repair
# 29                                Medical Terminology
# 30              General Physical Education Activities
# 31                        Material and Energy Balance
# 32                                        Microbilogy
# 33  Advanced Techniques for the Risk Analysis of T...
# 34                   Practicum in the Superintendency
# 35                               Nutrition Laboratory
# 36                         Human-Computer Interaction
# 37                  Weightli ing & Sports Condi oning
# 38  Introduction to Ethical Practices in Interpreting
# 39                                     Group Piano II
# 40                             NCBO for Int Read Writ
# 41                                    Intro to Speech
# 42            Introduction to Artificial Intelligence
# 43                         Introduction to Psychology
# 44       Accounting and Finance for Actuarial Science
# 45            PUBLIC RELATIONS PLANNING AND CAMPAIGNS
# 46                                  Health Assessment
# 47                     Information Technolog Security
# 48                              Internship Internship
# 49                                      Art History I
#
#                                           description  \
# 0   survey and analysis of cinema , including hist...
# 1   you will be provided with a practical understa...
# 2   there is a subtle balance between improvements...
# 3   this course provides a survey of research find...
# 4   rigorous introduction to chemistry of carbon -...
# 5   introduction to the study of the materials and...
# 6   prepares students for 100w through drafting , ...
# 7   administrative law affects every aspect of ame...
# 8   this course is an introductory course to resea...
# 9   course introduces main concepts of computer sc...
# 10  this unit will focus on a range of biological ...
# 11  an investigation of contemporary topics in mat...
# 12  mgmt 640 combines the study of financial accou...
# 13  this is an introductory course in computer gra...
# 14  this course provides a historical and philosop...
# 15  this course is comparative in nature and exami...
# 16  managers and human resources management profes...
# 17  anatomy and physiology ii is the second part o...
# 18  generalist practice “ in context ” is the core...
# 19  misunderstandings often arise when speakers of...
# 20  anatomy and physiology i is the first part of ...
# 21  in this course , the principle of the operatio...
# 22  a study of the fundamental operations of whole...
# 23  an introduction to fine art printmaking . tech...
# 24  english 1301    is    a study of the principle...
# 25  focuses on demonstrating knowledge of auto bod...
# 26  after studying the principles of morphological...
# 27  this is a seminar exploring the role of geneti...
# 28  fundamentals of engine operation , diagnosis a...
# 29  this course offers students engagement and int...
# 30  this course is designed to give students a cur...
# 31  [ NAME ] [ NAME ] is a required course in the ...
# 32  to familiarize students with the development o...
# 33  the course provides advanced tools for the ris...
# 34  a field - based course to provide superintende...
# 35  a hands - on study of human nutrition . the go...
# 36  the course deals with the basics of human - co...
# 37  the purpose of this class is to give the stude...
# 38  discusses personal and professional ethics wit...
# 39  a group course for students having limited but...
# 40  this course comprises the integration of criti...
# 41  introduces basic human communication principle...
# 42  an introductory course covering basic concepts...
# 43  a survey of the basic principles , research co...
# 44  this module is designed to provide an introduc...
# 45  public relations planning and campaigns is an ...
# 46  development of skills and techniques required ...
# 47  this best - selling guide provides a complete ...
# 48  field - based learning opportunities in the bi...
# 49  this course is exciting because you will learn...
#
#                                    top_50_esco_skills
# 0   [film studies, film production process, develo...
# 1   [quality control systems, statistical quality ...
# 2   [data ethics, business analytics, use analytic...
# 3   [marketing principles, satisfy customers, prom...
# 4   [organic chemistry, develop chemical products,...
# 5   [Earth science, use earth sciences tools, geoc...
# 6   [study relevant writing, teach writing, provid...
# 7   [make legislative decisions, legal department ...
# 8   [perform copywriting, teach journalistic pract...
# 9   [computer technology, computer engineering, pr...
# 10  [forensic anthropology, forensic pathology, pe...
# 11  [mathematical economics, mathematics, mathemat...
# 12  [financial management, manage financial aspect...
# 13  [design graphics, computer graphics, digital a...
# 14  [develop criminology theories, criminal law, c...
# 15  [analyse legal evidence, handle case evidence,...
# 16  [financial management, interpret financial sta...
# 17  [human physiology, cardiovascular system, endo...
# 18  [meet standards of practice in social services...
# 19  [interact verbally in English, interact verbal...
# 20  [human physiology, human anatomy, biomedical s...
# 21  [digital image processing, apply medical imagi...
# 22  [mathematics, apply numeracy skills, teach bas...
# 23  [printing techniques, printing plate making, p...
# 24  [academic English, literary criticism, literar...
# 25  [carry out repair of vehicles, carry out repai...
# 26  [understand written Arabic, interact verbally ...
# 27  [behavioural science, genetics, design plans t...
# 28  [engine components, repair engines, comply wit...
# 29  [communicate in healthcare, communicate in spe...
# 30  [integrate exercise science to the design of t...
# 31  [materials engineering, chemical processes, an...
# 32  [microbiology-bacteriology, perform microbiolo...
# 33  [design strategies for nuclear emergencies, en...
# 34  [education administration, supervise education...
# 35  [conduct nutrition research, perform nutrition...
# 36  [human-computer interaction, usability enginee...
# 37  [biomechanics of sport performance, execute sp...
# 38  [provide advocacy interpreting services, follo...
# 39  [music literature, subject of music coaching, ...
# 40  [study relevant writing, teach writing, teach ...
# 41  [communication principles, teach public speaki...
# 42  [principles of artificial intelligence, comput...
# 43  [cognitive psychology, psychology, psychologic...
# 44  [financial management, manage financial aspect...
# 45  [advise on public relations, develop public re...
# 46  [undertake clinical audit, provide clinical ps...
# 47  [cyber security, security engineering, ICT sec...
# 48  [teach biology, take advantage of learning opp...
# 49  [study artworks, art history, teach art studie...
